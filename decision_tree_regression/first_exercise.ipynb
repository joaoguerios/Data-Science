# %% [markdown]
# <h1>Decisionm Tree Regression</h1>

# %% [markdown]
# <h3>Libraries</h3>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.tree import DecisionTreeRegressor

# %% [markdown]
# <h3>Data</h3>

# %%
df = pd.read_csv("Data.csv")
df_infos = df.iloc[:,1:-1].values
df_results = df.iloc[:,-1].values

# %% [markdown]
# <h3>Model</h3>

# %%
regressor = DecisionTreeRegressor(random_state=0)
regressor.fit(df_infos,df_results)
# Out:
# DecisionTreeRegressor(random_state=0)

# %%
infos_grid = np.arange(min(df_infos), max(df_infos), 0.1)
infos_grid = infos_grid.reshape((len(infos_grid),1))
df_pred = regressor.predict(infos_grid)
# Out:
# C:\Users\joaop\AppData\Local\Temp\ipykernel_2896\2573284980.py:1: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   infos_grid = np.arange(min(df_infos), max(df_infos), 0.1)

# %%
regressor.predict([[6.5]])
# Out:
# array([150000.])

# %% [markdown]
# <h3>Visualizing</h3>

# %%
plt.scatter(df_infos,df_results, color = "red", label = "Data")
plt.plot(infos_grid, df_pred, color = "blue", label = "results")
plt.title("Decision tree")
plt.xlabel("level")
plt.ylabel("Salary")
plt.show()
